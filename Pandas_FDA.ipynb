# %% [markdown]
# <a href="https://colab.research.google.com/github/Hellohiavinash/Machine_Learning_Projects/blob/main/Pandas_FDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Downloading and unzipping the dataset
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# !unzip zomato_dataset.zip
# !mv zomato_dataset.csv.
# Out:
# --2026-09-23 15:47:00--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 13.225.41.45, 13.225.41.18, 13.225.41.124, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|13.225.41.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip’
#
# zomato_dataset.zip  100%[===================>]  69.24M   136MB/s    in 0.5s
#
# 2026-09-23 15:47:01 (136 MB/s) - ‘zomato_dataset.zip’ saved [72602133/72602133]
#
# Archive:  zomato_dataset.zip
#   inflating: zomato_dataset.csv
# mv: missing destination file operand after 'zomato_dataset.csv.'
# Try 'mv --help' for more information.

# %%
import pandas as pd

df=pd.read_csv('/content/zomato_dataset.csv')
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
#charateristics of the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
# ...

# %%
df.describe()
# Out:
#               votes
# count  23193.000000
# mean     601.074462
# std     1114.854301
# min        0.000000
# 25%      101.000000
# 50%      221.000000
# 75%      586.000000
# max    16832.000000

# %%
df.shape
# Out:
# (23193, 17)

# %%
df['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 23188    3.8 /5
# 23189    3.9 /5
# 23190    2.8 /5
# 23191    2.5 /5
# 23192    4.3 /5
# Name: rate, Length: 23193, dtype: object

# %%
df['rate'].shape
# Out:
# (23193,)

# %%
x= ['rate', 'votes']
df[x]
# Out:
#          rate  votes
# 0       4.1/5    775
# 1       4.1/5    787
# 2       3.8/5    918
# 3       3.7/5     88
# 4       3.8/5    166
# ...       ...    ...
# 23188  3.8 /5    128
# 23189  3.9 /5     77
# 23190  2.8 /5    161
# 23191  2.5 /5     81
# 23192  4.3 /5    236
#
# [23193 rows x 2 columns]

# %%
df[['rate','votes']]
# Out:
#          rate  votes
# 0       4.1/5    775
# 1       4.1/5    787
# 2       3.8/5    918
# 3       3.7/5     88
# 4       3.8/5    166
# ...       ...    ...
# 23188  3.8 /5    128
# 23189  3.9 /5     77
# 23190  2.8 /5    161
# 23191  2.5 /5     81
# 23192  4.3 /5    236
#
# [23193 rows x 2 columns]

# %%
#fetch the 50th row
#fetch it using index location

df.iloc[49]
# Out:
# url                            https://www.zomato.com/bangalore/rolls-on-whee...
# address                        Shop 33 & 30, 21st Main, Near BDA Complex, 2nd...
# name                                                             Rolls On Wheels
# online_order                                                                  No
# book_table                                                                    No
# rate                                                                       3.6/5
# votes                                                                        299
# phone                                           +91 9071734101\r\n+91 9071496800
# location                                                            Banashankari
# rest_type                                                            Quick Bites
# dish_liked                     Rolls, Momos, Fries, Veggie Roll, Chicken Keba...
# cuisines                                                 Fast Food, Rolls, Momos
# ...

# %%
df.iloc[2:10]
# Out:
#                                                  url  \
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/onesta-banash...
# 7  https://www.zomato.com/bangalore/penthouse-caf...
# 8  https://www.zomato.com/bangalore/smacznego-ban...
# 9  https://www.zomato.com/bangalore/caf%C3%A9-dow...
#
#                                              address  \
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6  2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 7  1, 30th Main Road, 3rd Stage, Banashankari, Ba...
# 8  2470, 21 Main Road, 25th Cross, Banashankari, ...
# 9  12,29 Near PES University Back Gate, D'Souza N...
#
# ...

# %%
df_explict= df.set_index("name")

# %%
df_explict.columns
# Out:
# Index(['url', 'address', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df_explict.head()
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
#
#                                                                  address  \
# name
# Jalsa                  942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant         2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village          10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                       online_order book_table   rate  votes  \
# name
# ...

# %%
df_explict.loc['Jalsa']
# Out:
#                                                      url  \
# name
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
#
#                                                  address online_order  \
# name
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
df_explict.loc['Suraaj']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Suraaj'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2135/1511407371.py in <cell line: 0>()
# ----> 1 df_explict.loc['Suraaj']
#
# ...

# %%
df_explict.reset_index(inplace=True)

# %%
df_explict.head()
# Out:
#                     name                                                url  \
# 0                  Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# 1         Spice Elephant  https://www.zomato.com/bangalore/spice-elephan...
# 2        San Churro Cafe  https://www.zomato.com/SanchurroBangalore?cont...
# 3  Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# 4          Grand Village  https://www.zomato.com/bangalore/grand-village...
#
#                                              address online_order book_table  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes        Yes
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...          Yes         No
# 2  1112, Next to KIMS Medical College, 17th Cross...          Yes         No
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...           No         No
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...           No         No
#
# ...

# %%
df_explict.columns
# Out:
# Index(['name', 'url', 'address', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df= df.rename(columns={'approx_cost(for two people)': 'cost_for_two','rate':'ratings'})

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table ratings  votes                             phone  \
# 0          Yes        Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df['only_ratings']= df['ratings'].str[:-2] #more options

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table ratings  votes                             phone  \
# 0          Yes        Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              23193 non-null  object
#  1   address          23193 non-null  object
#  2   name             23193 non-null  object
#  3   online_order     23193 non-null  object
#  4   book_table       23193 non-null  object
#  5   ratings          23193 non-null  object
#  6   votes            23193 non-null  int64
#  7   phone            23193 non-null  object
#  8   location         23193 non-null  object
#  9   rest_type        23193 non-null  object
#  10  dish_liked       23193 non-null  object
#  11  cuisines         23193 non-null  object
#  12  cost_for_two     23193 non-null  object
#  13  reviews_list     23193 non-null  object
#  14  menu_item        23193 non-null  object
#  15  listed_in(type)  23193 non-null  object
# ...

# %%
df['only_ratings']= df['only_ratings'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2135/2886299977.py in <cell line: 0>()
# ----> 1 df['only_ratings']= df['only_ratings'].astype(float)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
df['only_ratings'].replace('N','0.0',inplace=True)

# %%
df['only_ratings']= df['only_ratings'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              23193 non-null  object
#  1   address          23193 non-null  object
#  2   name             23193 non-null  object
#  3   online_order     23193 non-null  object
#  4   book_table       23193 non-null  object
#  5   ratings          23193 non-null  object
#  6   votes            23193 non-null  int64
#  7   phone            23193 non-null  object
#  8   location         23193 non-null  object
#  9   rest_type        23193 non-null  object
#  10  dish_liked       23193 non-null  object
#  11  cuisines         23193 non-null  object
#  12  cost_for_two     23193 non-null  object
#  13  reviews_list     23193 non-null  object
#  14  menu_item        23193 non-null  object
#  15  listed_in(type)  23193 non-null  object
# ...

# %%
####
###Another version of Zomato's Dataset

# !gdown 1YBEwvF07zaNNqW8sMPrwmgl4s73EPU_S
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1YBEwvF07zaNNqW8sMPrwmgl4s73EPU_S
# From (redirected): https://drive.google.com/uc?id=1YBEwvF07zaNNqW8sMPrwmgl4s73EPU_S&confirm=t&uuid=e67df8e6-c540-41c9-aaa1-13d06e2d9a98
# To: /content/data.csv
# 100% 486M/486M [00:06<00:00, 76.4MB/s]

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_Votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# ...

# %%
## 1. Finding unique values in the 'location' column
## 2. Count the unique values in 'location column
##3. Find the occurance of each unique value in the location column

# %%
df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Jayanagar', 'Kumaraswamy Layout',
#        'Rajarajeshwari Nagar', 'Mysore Road', 'Uttarahalli',
#        'South Bangalore', 'Vijay Nagar', 'Bannerghatta Road', 'JP Nagar',
#        'BTM', 'Wilson Garden', 'Koramangala 5th Block', 'Shanti Nagar',
#        'Richmond Road', 'City Market', 'Bellandur', 'Sarjapur Road',
#        'Marathahalli', 'HSR', 'Old Airport Road', 'Indiranagar',
#        'Koramangala 1st Block', 'East Bangalore', 'MG Road',
#        'Brigade Road', 'Lavelle Road', 'Church Street', 'Ulsoor',
#        'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road', 'Domlur',
#        'Koramangala 8th Block', 'Frazer Town', 'Ejipura', 'Vasanth Nagar',
#        'Jeevan Bhima Nagar', 'Old Madras Road', 'Commercial Street',
#        'Koramangala 6th Block', 'Majestic', 'Langford Town',
#        'Koramangala 7th Block', 'Brookefield', 'Whitefield',
# ...

# %%
df['location'].nunique()
# Out:
# 88

# %%
df['location'].value_counts()
# Out:
# location
# Koramangala 5th Block    1783
# BTM                      1456
# Indiranagar              1350
# HSR                      1162
# Jayanagar                1037
#                          ...
# Kanakapura Road             2
# West Bangalore              2
# Yelahanka                   2
# Magadi Road                 2
# KR Puram                    1
# Name: count, Length: 88, dtype: int64

# %%
## Select the last two rows and the last column
df.iloc[-2:, -1 ]
# Out:
# 23191    False
# 23192     True
# Name: is_good, dtype: bool

# %%
df.iloc[-2:, -1: ]
# Out:
#        is_good
# 23191    False
# 23192     True

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R4"],
    "Votes": [120, 240, 150, 80],
    "Rating": [4.1, 4.5, 3.9, 4.0]
}

sample_df = pd.DataFrame(data)

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0

# %%
sample_df.iloc[1:3, 1:3]=[[300,4.7],[200,3.7]]

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    200     3.7
# 3         R4     80     4.0

# %%
#misc but very useful
sample_df= sample_df.set_index('Restaurant')

# %%
sample_df.loc['R2']
# Out:
# Votes     300.0
# Rating      4.7
# Name: R2, dtype: float64

# %%
sample_df
# Out:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            300     4.7
# R3            200     3.7
# R4             80     4.0

# %%
sample_df.loc['R2','Votes']=200

# %%
sample_df
# Out:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            200     4.7
# R3            200     3.7
# R4             80     4.0

# %%
data = {
    "Restaurant": ["R1", "R2", "R3", "R4"],
    "Votes": [120, 240, 150, 80],
    "Rating": [4.1, 4.5, 3.9, 4.0]
}

new_df = pd.DataFrame(data)

# %%
demo_df=new_df.set_index('Restaurant')

# %%
demo_df.loc['R2', 'Votes']= 200

# %%
demo_df
# Out:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            200     4.5
# R3            150     3.9
# R4             80     4.0

# %%
data = {
    "Restaurant": ["R1", "R2", "R3", "R4"],
    "Votes": [120, 240, 150, 80],
    "Rating": [4.1, 4.5, 3.9, 4.0]
}

final_df = pd.DataFrame(data)

# %%
final_df.loc[final_df['Restaurant']=='R2','Votes']= 200

# %%
final_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    200     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0

# %%
#3-4 questions in detailed notes

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df[sample_df.duplicated()]
# Out:
#   Restaurant  Votes  Rating
# 3         R2    240     4.5
# 5         R1    120     4.1

# %%
new_df= sample_df.drop_duplicates()

# %%
new_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
#HW-->>>> keep='first', keep=False

# %%
sample_df['Restaurant'].drop_duplicates()
# Out:
# 0    R1
# 1    R2
# 2    R3
# 4    R4
# Name: Restaurant, dtype: object

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df['Rating'].sum()
# Out:
# np.float64(25.1)

# %%
sample_df['Rating'].mean()
# Out:
# np.float64(4.183333333333334)

# %%
sample_df['Rating'].agg(['sum','mean','min','max'])
# Out:
# sum     25.100000
# mean     4.183333
# min      3.900000
# max      4.500000
# Name: Rating, dtype: float64

# %%
sample_df['Rating'].describe()
# Out:
# count    6.000000
# mean     4.183333
# std      0.256255
# min      3.900000
# 25%      4.025000
# 50%      4.100000
# 75%      4.400000
# max      4.500000
# Name: Rating, dtype: float64

# %%
sample_df.describe()
# Out:
#             Votes    Rating
# count    6.000000  6.000000
# mean   158.333333  4.183333
# std     67.057190  0.256255
# min     80.000000  3.900000
# 25%    120.000000  4.025000
# 50%    135.000000  4.100000
# 75%    217.500000  4.400000
# max    240.000000  4.500000

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.sort_values(by='Votes', ascending=True)
# Out:
#   Restaurant  Votes  Rating
# 4         R4     80     4.0
# 0         R1    120     4.1
# 5         R1    120     4.1
# 2         R3    150     3.9
# 3         R2    240     4.5
# 1         R2    240     4.5

# %%
sample_df.sort_values(by='Votes', ascending=False)
# Out:
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 3         R2    240     4.5
# 2         R3    150     3.9
# 0         R1    120     4.1
# 5         R1    120     4.1
# 4         R4     80     4.0

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R7", "R4", "R8"],
    "Votes": [120, 240, 150, 241, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.2]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R7    241     4.5
# 4         R4     80     4.0
# 5         R8    120     4.2

# %%
sample_df.sort_values(by=['Votes','Rating'], ascending=[False,False])
# Out:
#   Restaurant  Votes  Rating
# 3         R7    241     4.5
# 1         R2    240     4.5
# 2         R3    150     3.9
# 5         R8    120     4.2
# 0         R1    120     4.1
# 4         R4     80     4.0
